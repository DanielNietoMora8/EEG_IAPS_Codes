# %%
import scipy
import mne
import matplotlib.pyplot as plt
import numpy as np
import scipy.io as sio
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import pickle
import pywt
from scipy import signal
from sklearn import svm
import statistics as stats
from sklearn.decomposition import PCA
from scipy.signal import butter, lfilter
from scipy.stats import kurtosis
from scipy.stats import skew
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score as acc
from os import path
import os

# %%
load_path = ('../Excombatants/IAPS crudos/Controles/01_Preprocessed/')
EEG_Files = os.listdir(load_path)
epochs_name= ['Negative','Neutral','Positive']

#Loading Subject's Epochs Files

EEG_data_con = np.zeros([3,19,62,128])


for file in range(0,len(EEG_Files)):
    _subject= file
    print('ANALIZING SUBJECT %02d' %(file))
    file_exist = 0
    try:
        
        filename = (load_path+EEG_Files[_subject])
        epochs = mne.read_epochs(filename).pick_types(eeg=True,eog = False)  
        epochs_r = epochs.copy().resample(128, npad='auto')
        #evoked = epochs_r.average()
        #print(epochs_r.get_data().shape)
        file_exist = 1

    except:
        print('ERROR:',filename + ' not found')

    #Setting the epochs by IAPS Valence
    evoked_neg=epochs_r['10'].average().data
    evoked_neu=epochs_r['11'].average().data
    evoked_pos=epochs_r['12'].average().data

    EEG_data_con[0,file,:,:] = evoked_neg
    EEG_data_con[1,file,:,:] = evoked_neu
    EEG_data_con[2,file,:,:] = evoked_pos
# Out:
# ANALIZING SUBJECT 00
# Reading ../Excombatants/IAPS crudos/Controles/01_Preprocessed/PE_C019_IAPS_epo.fif ...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 62) active
#     Found the data of interest:
#         t =    -200.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 204 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# ../Excombatants/IAPS crudos/Controles/01_Preprocessed/PE_C019_IAPS_epo.fif
# <EpochsFIF  |   204 events (all good), -0.2 - 0.792188 sec, baseline [-0.2, 0], ~12.5 MB, data loaded,
#  '10': 69
#  '11': 65
#  '12': 70>
# ANALIZING SUBJECT 01
# Reading ../Excombatants/IAPS crudos/Controles/01_Preprocessed/PE_C020_IAPS_epo.fif ...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 62) active
#     Found the data of interest:
# ...

# %%
load_path = ('../Excombatants/IAPS crudos/Casos/Medida 1/01_Preprocessed/')
EEG_Files = os.listdir(load_path)
epochs_name= ['Negative','Neutral','Positive']

#Loading Subject's Epochs Files

EEG_data_casos = np.zeros([3,31,62,128])


for file in range(0,len(EEG_Files)):
    _subject= file
    print('ANALIZING SUBJECT %02d' %(file))
    file_exist = 0
    try:
        
        filename = (load_path+EEG_Files[_subject])
        epochs = mne.read_epochs(filename).pick_types(eeg=True,eog = False)  
        epochs_r = epochs.copy().resample(128, npad='auto')
        #evoked = epochs_r.average()
        #print(epochs_r.get_data().shape)
        file_exist = 1

    except:
        print('ERROR:',filename + ' not found')

    #Setting the epochs by IAPS Valence
    evoked_neg=epochs_r['10'].average().data
    evoked_neu=epochs_r['11'].average().data
    evoked_pos=epochs_r['12'].average().data

    EEG_data_casos[0,file,:,:] = evoked_neg
    EEG_data_casos[1,file,:,:] = evoked_neu
    EEG_data_casos[2,file,:,:] = evoked_pos
# Out:
# ANALIZING SUBJECT 00
# Reading ../Excombatants/IAPS crudos/Casos/Medida 1/01_Preprocessed/PE_I022_IAPS_epo.fif ...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 62) active
#     Found the data of interest:
#         t =    -200.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 238 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# ANALIZING SUBJECT 01
# Reading ../Excombatants/IAPS crudos/Casos/Medida 1/01_Preprocessed/PE_I012_IAPS_epo.fif ...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 62) active
#     Found the data of interest:
#         t =    -200.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 225 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# ...

# %%
EEG = np.append(EEG_data_casos,EEG_data_con,axis = 1)
y = np.ones((50,1))
y[31:] = - 1 

import pickle
file= open('Wavelets_Excombatants/EEG.pckl', 'wb')
pickle.dump(EEG,file)
file.close()

file= open('Wavelets_Excombatants/y.pckl', 'wb')
pickle.dump(y,file)
file.close()

# %%
print(EEG[2,:,:]==EEG[1,:,:])
# Out:
# [[[False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]
#   ...
#   [False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]]
#
#  [[False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]
#   ...
#   [False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]]
#
#  [[False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]
#   ...
#   [False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]]
#
#  ...
#
#  [[False False False ... False False False]
#   [False False False ... False False False]
# ...
